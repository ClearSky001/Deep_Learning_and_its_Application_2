# %% [markdown]
# Convolutional neural Network
# ============================
#
# 이번 실습에서는 지난 시간에 작성한 코드의 사용성을 더 개선하고 간단한 CNN모델을 구현해본다.
# 1. custom datasets 작성하기
# 2. W&B를 이용하여 학습및 평가 트래킹하기
# 3. CNN모델 구현하기

# %% [markdown]
# ### Custom datasets 작성하기
# ``torch.utils.data.Dataset``는 dataset을 위한 추상클래스이다. custom dataset은 이 클래스를 상속하고 아래 두가지 메서드를 override하여야 한다:
#
#
#
# * `__len__`을 구현하여 len(dataset)이 데이터셋 크기를 리턴한다
#
# * `__getitem__` 을 구현하여 dataset[i] 와 같은 인덱싱에서 i번째 샘플을 리턴한다.

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class CustomDatasetExample(Dataset):
    def __init__ (self , X, y):
        self.X = X
        self.y = y
        assert len(X) == len(y)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
data_x = torch.rand([10, 3], dtype=torch.float32) #example tensor dataset with 3 feature and 10 examples
data_y = torch.arange(10) # target y

example_dataset = CustomDatasetExample(data_x, data_y)
print(f"Dataset 크기: {len(example_dataset)}")
print(f"4-th example: {example_dataset[3]}\n")
for X, y in example_dataset:
    print(X, y)
# Out:
# Dataset 크기: 10
# 4-th example: (tensor([0.0248, 0.3157, 0.1669]), tensor(3))
#
# tensor([0.8620, 0.3773, 0.8612]) tensor(0)
# tensor([0.5003, 0.9071, 0.6693]) tensor(1)
# tensor([0.4618, 0.6176, 0.1285]) tensor(2)
# tensor([0.0248, 0.3157, 0.1669]) tensor(3)
# tensor([0.5258, 0.9286, 0.4945]) tensor(4)
# tensor([0.6475, 0.4823, 0.9471]) tensor(5)
# tensor([0.3926, 0.3010, 0.6819]) tensor(6)
# tensor([0.3296, 0.4351, 0.5542]) tensor(7)
# tensor([0.9969, 0.2016, 0.9531]) tensor(8)
# tensor([0.0551, 0.6998, 0.7899]) tensor(9)

# %% [markdown]
# 이제 아래 csv파일로 부터 이미지 경로와 라벨 정보를 읽어오는 사용자정의 dataset을 구현해보자

# %%
pd.read_csv('resources/cat_dog_images/meta.csv')
# Out:
#               image_path label
# 0  images_001/dog-01.jpg   dog
# 1  images_001/cat-01.jpg   cat
# 2  images_002/dog-02.jpg   dog
# 3  images_002/cat-02.jpg   cat
# 4  images_002/dog-03.jpg   dog
# 5  images_001/cat-03.jpg   cat

# %% [markdown]
# <mark>과제</mark>: root directory의 경로 "resources/cat_dog_images"와 이미지의 경로 및 label를 저장하고 있는 메타데이터 meta.csv파일을 입력으로 받는 custom datsets을 구현하라
#
# * 이미지를 읽는데에는 [PIL.Image.open](https://pillow.readthedocs.io/en/stable/reference/Image.html) 함수를 사용할 것.

# %%
from PIL import Image
import os

class CustomImageDataset(Dataset):
    def __init__(self, root_dir, metadata_filename, transform=None, target_transform=None):
        self.metadata_df = pd.read_csv(os.path.join(root_dir, metadata_filename))
        self.root_dir = root_dir

        classes = self.metadata_df["label"].drop_duplicates().sort_values().tolist()
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}

        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        ##### YOUR CODE START #####
        return len(self.metadata_df)
        ##### YOUR CODE END #####

    def __getitem__(self, idx):
        ##### YOUR CODE START #####
        img_path = os.path.join(self.root_dir, self.metadata_df.iloc[idx, 0]) # 첫 번째 컬럼에 이미지 경로가 있다고 가정
        label_str = self.metadata_df.iloc[idx, 1] # 두 번째 컬럼에 레이블이 있다고 가정

        # 이미지 파일을 읽음
        image = Image.open(img_path).convert("RGB")
        ##### YOUR CODE END #####

        label = self.class_to_idx[label_str] # encode label to integer

        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)

        return image, label

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

custom_dataset = CustomImageDataset(root_dir = 'resources/cat_dog_images', 
                                                   metadata_filename = "meta.csv",
                                                   transform = transform)

for i in range(len(custom_dataset)):
    image, target = custom_dataset[i]
    print(f"{i+1}-th example: X.shape = {image.shape}, label = {target}")
# Out:
# 1-th example: X.shape = torch.Size([3, 800, 1200]), label = 1
# 2-th example: X.shape = torch.Size([3, 900, 1200]), label = 0
# 3-th example: X.shape = torch.Size([3, 800, 1200]), label = 1
# 4-th example: X.shape = torch.Size([3, 900, 1200]), label = 0
# 5-th example: X.shape = torch.Size([3, 900, 1200]), label = 1
# 6-th example: X.shape = torch.Size([3, 900, 742]), label = 0

# %%
def visualize_samples(dataset, cols=8, rows=5):
    figure = plt.figure(figsize=(12, 6))
    for i in range(len(dataset)):
        img, label = dataset[i]
        figure.add_subplot(rows, cols, i+1)
        plt.title(label)
        plt.axis("off")
        plt.imshow(img.numpy().transpose((1, 2, 0)))
    plt.show()

# %%
visualize_samples(custom_dataset, rows = 2 , cols = 3)

# %% [markdown]
# 하지만 모든 샘플의 이미지 크기가 같지 않기 때문에 아래와 같이 dataloader를 이용해 mini-batch로 쌓으려고 하면 오류가 생긴다.

# %%
train_dataloader = DataLoader(dataset= custom_datset, batch_size=6, shuffle=True)
for X, y in train_dataloader:
    print(X.shape, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 train_dataloader = DataLoader(dataset= custom_datset, batch_size=6, shuffle=True)
# ----> 2 for X, y in train_dataloader:
#       3     print(X.shape, y)
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[5], line 39, in CustomImageDataset.__getitem__(self, idx)
#      36 label = self.class_to_idx[label_str] # encode label to integer
#      38 if self.transform:
# ---> 39     image = self.transform(image)
#      40 if self.target_transform:
#      41     label = self.target_transform(label)
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File /opt/conda/lib/python3.11/site-packages/torchvision/transforms/functional.py:142, in to_tensor(pic)
#     140     _log_api_usage_once(to_tensor)
#     141 if not (F_pil._is_pil_image(pic) or _is_numpy(pic)):
# --> 142     raise TypeError(f"pic should be PIL Image or ndarray. Got {type(pic)}")
#     144 if _is_numpy(pic) and not _is_numpy_image(pic):
#     145     raise ValueError(f"pic should be 2/3 dimensional. Got {pic.ndim} dimensions.")
#
# TypeError: pic should be PIL Image or ndarray. Got <class 'torch.Tensor'>

# %% [markdown]
# 따라서 transforms를 이용한 전처리가 필요하다.
# ``torchvision.transforms``에 다양한 이미지 전처리 함수가 이미 구현되어있다. 자세히는 [documentation](https://pytorch.org/vision/main/transforms.html)을 참고하기 바란다.
#
# 여기서는 그 중 자주 사용되는 몇 가지를 소개한다.

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

custom_datset_train = CustomImageDataset(root_dir = 'resources/cat_dog_images', 
                                   metadata_filename = "meta.csv",
                                   transform = train_transform)

visualize_samples(custom_datset_train, rows = 2 , cols = 3)
visualize_samples(custom_datset_train, rows = 2 , cols = 3)

# %% [markdown]
# 데이터를 뽑을때 마다 랜덤하게 다른 augmented image가 출력되는것을 확인할 수 있다.
# 데이터로더에서도 (3, 224, 224) 크기의 이미지가 잘 출력됨을 확인할 수 있다

# %%
train_dataloader = DataLoader(dataset= custom_datset_train, batch_size=6, shuffle=True)
for X, y in train_dataloader:
    print(X.shape, y)
# Out:
# torch.Size([6, 3, 224, 224]) tensor([1, 0, 1, 0, 1, 0])

# %% [markdown]
# ### custom Sampler로 weighted sampling하기
#
# Sampler는 dataloader가 data를 추출하는 순서를 정해주는 객체로 datasets의 index를 순차적으로 리턴하는 iterator이다.
#
# ``__iter__``에서는 데이터셋의 순서를 정하는 로직을 통과한 뒤 그 인덱스들을 순회할수 있는 iterator를 반환한다.
#
# 아래 예시는 label imbalance를 해결하기 위해 각 class로 부터 같은 숫자의 샘플들을 추출하는 샘플러이다.

# %%
from torch.utils.data import Sampler
import random

class BalancedSampler(Sampler): 
    def __init__(self, dataset, class_column_name='label'):
        """
        Args:
            dataset: The dataset to sample from.
            class_column_name: The column name in the dataset that contains class labels.
        """
        self.dataset = dataset
        self.class_column_name = class_column_name
        
        # Group indices by class
        self.class_indices = {}
        for idx, label in enumerate(self.dataset.metadata_df[class_column_name]):
            if label not in self.class_indices:
                self.class_indices[label] = []
            self.class_indices[label].append(idx)
        
        self.min_class_length = min(len(indices) for indices in self.class_indices.values())
        
    def __iter__(self):
        selected_indices = []

        for class_name, indices in self.class_indices.items():
            sampled_indices = random.sample(indices, self.min_class_length)
            selected_indices.extend(sampled_indices)
        
        random.shuffle(selected_indices)
        return iter(selected_indices)
    
    def __len__(self):
        # The length of the sampler will be twice the minimum class length since we are balancing
        return self.min_class_length * len(self.class_indices)

# %%
custom_datset_imbalance = CustomImageDataset(root_dir = 'resources/cat_dog_images', 
                                   metadata_filename = "meta_imbalanced.csv",
                                   transform = train_transform)

print(f"this dataset has imbalanced label :{[target for image,target in custom_datset_imbalance]}\n")

balanced_sampler = BalancedSampler(custom_datset_imbalance)
print(f"class to dataset index dict: {balanced_sampler.class_indices}")
print(f"sampled index : {[idx for idx in balanced_sampler]}\n")

dataloader = DataLoader(custom_datset_imbalance, batch_size=32, sampler=balanced_sampler)
for X, y in dataloader:
    print(f"mini-batch X.shape = {X.shape}, target y = {y}")
# Out:
# this dataset has imbalanced label :[0, 1, 0, 1, 0]
#
# class to dataset index dict: {'cat': [0, 2, 4], 'dog': [1, 3]}
# sampled index : [3, 4, 1, 2]
#
# mini-batch X.shape = torch.Size([4, 3, 224, 224]), target y = tensor([1, 0, 0, 1])

# %% [markdown]
# ### 학습 코드 개선하기
#
# 아래는 지난 실습에서 작성한 학습코드를 다음의 측면에서 개선한 코드이다. 코드를 리뷰하며 다시 복습해보자.
#
# - tqdm을 이용학 학습 시간 추적
# - AverageMeter를 사용하여 학습 metric을 추적
# - save_checkpoint와 load_checkpoint를 이용하여 모델을 저장하고 불러오는 기능 추가

# %%
import os, time, shutil

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import wandb

# %%
def load_MNIST_datasets(data_root_dir):
    transform = transforms.Compose([
        transforms.ToTensor(),
    ])
    
    train_dataset = datasets.MNIST(
        root=data_root_dir, train=True, download=True, 
        transform=transform
    )
    test_dataset = datasets.MNIST(
        root=data_root_dir, train=False, download=True, 
        transform=transform
    )

    return train_dataset, test_dataset

# %%
def create_dataloaders(train_dataset, test_dataset, device, batch_size, num_worker):
    kwargs = {}
    if device.startswith("cuda"):
        kwargs.update({
            'pin_memory': True,
        })

    train_dataloader = DataLoader(dataset = train_dataset, batch_size=batch_size, 
                                  shuffle=True, num_workers=num_worker, **kwargs)
    test_dataloader = DataLoader(dataset = test_dataset, batch_size=batch_size, 
                                 shuffle=False, num_workers=num_worker, **kwargs)
    
    return train_dataloader, test_dataloader

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name}: {avg' + self.fmt + '} (n={count}))'
        return fmtstr.format(**self.__dict__)

def calculate_accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res
    
def save_checkpoint(filepath, model, optimizer, epoch, best_acc1, is_best, best_model_path):
    save_dir = os.path.split(filepath)[0]
    os.makedirs(save_dir, exist_ok=True)

    state = {
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'epoch': epoch + 1,
        'best_acc1': best_acc1,
    }
    
    torch.save(state, filepath)
    if is_best:
        shutil.copyfile(filepath, best_model_path)


def load_checkpoint(filepath, model, optimizer, device):
    if os.path.isfile(filepath):
        checkpoint = torch.load(filepath, map_location=device)
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        start_epoch = checkpoint['epoch']
        best_acc1 = checkpoint['best_acc1']
        print(f"=> loaded checkpoint '{filepath}' (epoch {start_epoch})")
        return start_epoch, best_acc1
    else:
        print(f"=> no checkpoint found at '{filepath}'")
        return 0, 0

# %%
def train_loop(model, device, dataloader, criterion, optimizer, epoch):
    # train for one epoch
    losses = AverageMeter('Loss', ':.4e')
    acc_top1 = AverageMeter('Acc@1', ':6.2f')
    data_time = AverageMeter('Data_Time', ':6.3f') # Time for data loading
    batch_time = AverageMeter('Batch_Time', ':6.3f') # time for mini-batch train
    metrics_list = [losses, acc_top1, data_time, batch_time, ]
    
    model.train() # switch to train mode

    end = time.time()

    tqdm_epoch = tqdm(dataloader, desc=f'Training Epoch {epoch + 1}', total=len(dataloader))
    for images, target in tqdm_epoch:
        data_time.update(time.time() - end)

        images = images.to(device, non_blocking=True)
        target = target.to(device, non_blocking=True)

        output = model(images)
        loss = criterion(output, target)

        acc1, = calculate_accuracy(output, target, topk=(1,))
        losses.update(loss.item(), images.size(0))
        acc_top1.update(acc1[0], images.size(0))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_time.update(time.time() - end)

        tqdm_epoch.set_postfix(avg_metrics = ", ".join([str(x) for x in metrics_list]))

        end = time.time()
    tqdm_epoch.close()

    ##### YOUR CODE START #####
    # wandb log following variables: losses.avg, acc_top1.avg
    wandb.log({
        "Train Loss": losses.avg,
        "Train Accuracy": acc_top1.avg,
        "Epoch": epoch + 1
    })
    ##### YOUR CODE END #####

# %%
def evaluation_loop(model, device, dataloader, criterion, epoch = 0):
    losses = AverageMeter('Loss', ':.4e')
    acc_top1 = AverageMeter('Acc@1', ':6.2f')
    metrics_list = [losses, acc_top1]

    model.eval() # switch to evaluate mode

    with torch.no_grad():
        tqdm_val = tqdm(dataloader, desc='Validation/Test', total=len(dataloader))
        for images, target in tqdm_val:
            images = images.to(device, non_blocking=True)
            target = target.to(device, non_blocking=True)

            output = model(images)
            loss = criterion(output, target)

            acc1, = calculate_accuracy(output, target, topk=(1,))
            losses.update(loss.item(), images.size(0))
            acc_top1.update(acc1[0], images.size(0))

            tqdm_val.set_postfix(avg_metrics = ", ".join([str(x) for x in metrics_list]))

        tqdm_val.close()

    ##### YOUR CODE START #####
    wandb.log({
        "Validation Loss": losses.avg,
        "Validation Accuracy": acc_top1.avg,
        "Epoch": epoch + 1
    })
    ##### YOUR CODE END #####

    return acc_top1.avg

# %%
class MultiLayerPerceptron(nn.Module):
    
    def __init__(self, in_dim, hidden_dim, out_dim):
        super().__init__()

        self.flatten = nn.Flatten()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        x = self.flatten(x)

        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_main_MLP():
    ## data and preprocessing settings
    data_root_dir = '/datasets' 
    num_worker = 4

    ## Hyper parameters
    batch_size = 128
    learning_rate = 1e-3
    start_epoch = 0
    num_epochs = 50

    ## checkpoint setting
    checkpoint_save_interval = 10
    checkpoint_path = "checkpoints/checkpoint.pth"
    best_model_path = "checkpoints/best_model.pth"
    load_from_checkpoint = None # Options: "latest", "best", or None

    ## variables
    best_acc1 = 0

    ## set learning deterministic
    # torch.manual_seed(1)

    ##### YOUR CODE START #####
    wandb.init(project="MNIST-MLP", config={
        "learning_rate": learning_rate,
        "epochs": num_epochs,
        "batch_size": batch_size
    })
    ##### YOUR CODE END #####


    device = "cuda:0" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
    print(f"Using {device} device")

    train_dataset, test_dataset = load_MNIST_datasets(data_root_dir)
    num_classes = len(train_dataset.classes)
    
    train_dataloader, test_dataloader = create_dataloaders(train_dataset, test_dataset, device, 
                                                           batch_size = batch_size, num_worker = num_worker)


    model = MultiLayerPerceptron(in_dim = 28*28, hidden_dim = 512, out_dim = num_classes).to(device)

    criterion = nn.CrossEntropyLoss().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

    if load_from_checkpoint:
        load_checkpoint_path = (best_model_path if load_from_checkpoint == "best" else checkpoint_path)
        start_epoch, best_acc1 = load_checkpoint(load_checkpoint_path, model, optimizer, device)

    for epoch in range(start_epoch, num_epochs):
        train_loop(model, device, train_dataloader, criterion, optimizer, epoch)
        acc1 = evaluation_loop(model, device, test_dataloader,criterion, epoch)


        is_best = acc1 > best_acc1
        best_acc1 = max(acc1, best_acc1)

        if (epoch + 1) % checkpoint_save_interval == 0 or is_best:
            save_checkpoint(checkpoint_path, model, optimizer, epoch, best_acc1, is_best, best_model_path)

    ##### YOUR CODE START #####
    wandb.finish()
    ##### YOUR CODE END #####

# %% [markdown]
# <mark>과제</mark> [wandb](https://kr.wandb.ai/) 회원가입을 하고 메뉴얼에 따라 Train Loss, Train Accuracy, Validation Loss, Validation Accuracy를 추적하도록 위 함수들을 적절히 수정하고 학습해보라

# %%
train_main_MLP()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jovyan/.netrc
# wandb version 0.18.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/jovyan/Deep_Learning_and_its_Application_2/lab_03/wandb/run-20240925_124531-0t92iufk</code>
# Syncing run <strong><a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/0t92iufk' target="_blank">sunny-frost-1</a></strong> to <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP</a>
#  View run at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/0t92iufk' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/0t92iufk</a>
# Using cuda:0 device
# Training Epoch 1: 100%|██████████| 469/469 [00:01<00:00, 357.71it/s, avg_metrics=Loss: 2.2923e+00 (n=60000)), Acc@1:  24.36 (n=60000)), Data_Time:  0.001 (n=469)), Batch_Time:  0.002 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 599.24it/s, avg_metrics=Loss: 2.2806e+00 (n=10000)), Acc@1:  34.75 (n=10000))]
# Training Epoch 2: 100%|██████████| 469/469 [00:00<00:00, 826.76it/s, avg_metrics=Loss: 2.2705e+00 (n=60000)), Acc@1:  41.74 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 475.43it/s, avg_metrics=Loss: 2.2569e+00 (n=10000)), Acc@1:  48.85 (n=10000))]
# Training Epoch 3: 100%|██████████| 469/469 [00:00<00:00, 695.83it/s, avg_metrics=Loss: 2.2455e+00 (n=60000)), Acc@1:  51.32 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 692.14it/s, avg_metrics=Loss: 2.2286e+00 (n=10000)), Acc@1:  56.77 (n=10000))]
# Training Epoch 4: 100%|██████████| 469/469 [00:00<00:00, 583.34it/s, avg_metrics=Loss: 2.2144e+00 (n=60000)), Acc@1:  58.01 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 590.98it/s, avg_metrics=Loss: 2.1926e+00 (n=10000)), Acc@1:  61.89 (n=10000))]
# Training Epoch 5: 100%|██████████| 469/469 [00:00<00:00, 775.58it/s, avg_metrics=Loss: 2.1742e+00 (n=60000)), Acc@1:  61.67 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 423.74it/s, avg_metrics=Loss: 2.1454e+00 (n=10000)), Acc@1:  64.79 (n=10000))]
# Training Epoch 6: 100%|██████████| 469/469 [00:00<00:00, 735.37it/s, avg_metrics=Loss: 2.1210e+00 (n=60000)), Acc@1:  64.05 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 413.48it/s, avg_metrics=Loss: 2.0827e+00 (n=10000)), Acc@1:  66.37 (n=10000))]
# Training Epoch 7: 100%|██████████| 469/469 [00:00<00:00, 731.62it/s, avg_metrics=Loss: 2.0505e+00 (n=60000)), Acc@1:  65.81 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 419.56it/s, avg_metrics=Loss: 2.0000e+00 (n=10000)), Acc@1:  68.03 (n=10000))]
# Training Epoch 8: 100%|██████████| 469/469 [00:00<00:00, 726.94it/s, avg_metrics=Loss: 1.9585e+00 (n=60000)), Acc@1:  68.13 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 445.56it/s, avg_metrics=Loss: 1.8935e+00 (n=10000)), Acc@1:  69.99 (n=10000))]
# Training Epoch 9: 100%|██████████| 469/469 [00:00<00:00, 741.77it/s, avg_metrics=Loss: 1.8422e+00 (n=60000)), Acc@1:  70.04 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 429.82it/s, avg_metrics=Loss: 1.7620e+00 (n=10000)), Acc@1:  71.53 (n=10000))]
# Training Epoch 10: 100%|██████████| 469/469 [00:00<00:00, 634.88it/s, avg_metrics=Loss: 1.7030e+00 (n=60000)), Acc@1:  71.68 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 518.17it/s, avg_metrics=Loss: 1.6098e+00 (n=10000)), Acc@1:  73.30 (n=10000))]
# Training Epoch 11: 100%|██████████| 469/469 [00:00<00:00, 707.63it/s, avg_metrics=Loss: 1.5478e+00 (n=60000)), Acc@1:  73.33 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 682.18it/s, avg_metrics=Loss: 1.4477e+00 (n=10000)), Acc@1:  74.99 (n=10000))]
# Training Epoch 12: 100%|██████████| 469/469 [00:00<00:00, 748.27it/s, avg_metrics=Loss: 1.3894e+00 (n=60000)), Acc@1:  75.00 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 446.00it/s, avg_metrics=Loss: 1.2904e+00 (n=10000)), Acc@1:  77.07 (n=10000))]
# Training Epoch 13: 100%|██████████| 469/469 [00:00<00:00, 716.77it/s, avg_metrics=Loss: 1.2414e+00 (n=60000)), Acc@1:  77.00 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 601.99it/s, avg_metrics=Loss: 1.1502e+00 (n=10000)), Acc@1:  78.72 (n=10000))]
# Training Epoch 14: 100%|██████████| 469/469 [00:00<00:00, 792.84it/s, avg_metrics=Loss: 1.1125e+00 (n=60000)), Acc@1:  78.53 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 424.20it/s, avg_metrics=Loss: 1.0315e+00 (n=10000)), Acc@1:  80.00 (n=10000))]
# Training Epoch 15: 100%|██████████| 469/469 [00:00<00:00, 729.68it/s, avg_metrics=Loss: 1.0048e+00 (n=60000)), Acc@1:  79.81 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 432.28it/s, avg_metrics=Loss: 9.3424e-01 (n=10000)), Acc@1:  81.00 (n=10000))]
# Training Epoch 16: 100%|██████████| 469/469 [00:00<00:00, 721.26it/s, avg_metrics=Loss: 9.1627e-01 (n=60000)), Acc@1:  80.89 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 419.35it/s, avg_metrics=Loss: 8.5441e-01 (n=10000)), Acc@1:  81.72 (n=10000))]
# Training Epoch 17: 100%|██████████| 469/469 [00:00<00:00, 642.94it/s, avg_metrics=Loss: 8.4342e-01 (n=60000)), Acc@1:  81.82 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 519.24it/s, avg_metrics=Loss: 7.8882e-01 (n=10000)), Acc@1:  82.71 (n=10000))]
# Training Epoch 18: 100%|██████████| 469/469 [00:00<00:00, 813.21it/s, avg_metrics=Loss: 7.8312e-01 (n=60000)), Acc@1:  82.56 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 424.97it/s, avg_metrics=Loss: 7.3418e-01 (n=10000)), Acc@1:  83.41 (n=10000))]
# Training Epoch 19: 100%|██████████| 469/469 [00:00<00:00, 628.85it/s, avg_metrics=Loss: 7.3266e-01 (n=60000)), Acc@1:  83.29 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 754.84it/s, avg_metrics=Loss: 6.8846e-01 (n=10000)), Acc@1:  84.04 (n=10000))]
# Training Epoch 20: 100%|██████████| 469/469 [00:00<00:00, 772.08it/s, avg_metrics=Loss: 6.9007e-01 (n=60000)), Acc@1:  83.86 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 512.59it/s, avg_metrics=Loss: 6.4968e-01 (n=10000)), Acc@1:  84.69 (n=10000))]
# Training Epoch 21: 100%|██████████| 469/469 [00:00<00:00, 715.85it/s, avg_metrics=Loss: 6.5382e-01 (n=60000)), Acc@1:  84.38 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 675.90it/s, avg_metrics=Loss: 6.1659e-01 (n=10000)), Acc@1:  85.33 (n=10000))]
# Training Epoch 22: 100%|██████████| 469/469 [00:00<00:00, 660.88it/s, avg_metrics=Loss: 6.2266e-01 (n=60000)), Acc@1:  84.93 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 692.42it/s, avg_metrics=Loss: 5.8801e-01 (n=10000)), Acc@1:  85.65 (n=10000))]
# Training Epoch 23: 100%|██████████| 469/469 [00:00<00:00, 659.82it/s, avg_metrics=Loss: 5.9567e-01 (n=60000)), Acc@1:  85.36 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 690.00it/s, avg_metrics=Loss: 5.6296e-01 (n=10000)), Acc@1:  86.04 (n=10000))]
# Training Epoch 24: 100%|██████████| 469/469 [00:00<00:00, 640.92it/s, avg_metrics=Loss: 5.7211e-01 (n=60000)), Acc@1:  85.75 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 638.86it/s, avg_metrics=Loss: 5.4155e-01 (n=10000)), Acc@1:  86.52 (n=10000))]
# Training Epoch 25: 100%|██████████| 469/469 [00:00<00:00, 775.24it/s, avg_metrics=Loss: 5.5149e-01 (n=60000)), Acc@1:  86.08 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 431.93it/s, avg_metrics=Loss: 5.2226e-01 (n=10000)), Acc@1:  86.87 (n=10000))]
# Training Epoch 26: 100%|██████████| 469/469 [00:00<00:00, 643.30it/s, avg_metrics=Loss: 5.3319e-01 (n=60000)), Acc@1:  86.47 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 457.51it/s, avg_metrics=Loss: 5.0527e-01 (n=10000)), Acc@1:  87.25 (n=10000))]
# Training Epoch 27: 100%|██████████| 469/469 [00:00<00:00, 739.50it/s, avg_metrics=Loss: 5.1701e-01 (n=60000)), Acc@1:  86.82 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 491.39it/s, avg_metrics=Loss: 4.9026e-01 (n=10000)), Acc@1:  87.53 (n=10000))]
# Training Epoch 28: 100%|██████████| 469/469 [00:00<00:00, 712.46it/s, avg_metrics=Loss: 5.0243e-01 (n=60000)), Acc@1:  87.03 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 404.72it/s, avg_metrics=Loss: 4.7676e-01 (n=10000)), Acc@1:  87.77 (n=10000))]
# Training Epoch 29: 100%|██████████| 469/469 [00:00<00:00, 732.01it/s, avg_metrics=Loss: 4.8945e-01 (n=60000)), Acc@1:  87.26 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 514.40it/s, avg_metrics=Loss: 4.6476e-01 (n=10000)), Acc@1:  88.00 (n=10000))]
# Training Epoch 30: 100%|██████████| 469/469 [00:00<00:00, 715.71it/s, avg_metrics=Loss: 4.7769e-01 (n=60000)), Acc@1:  87.51 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 412.10it/s, avg_metrics=Loss: 4.5358e-01 (n=10000)), Acc@1:  88.26 (n=10000))]
# Training Epoch 31: 100%|██████████| 469/469 [00:00<00:00, 737.40it/s, avg_metrics=Loss: 4.6702e-01 (n=60000)), Acc@1:  87.71 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 428.08it/s, avg_metrics=Loss: 4.4357e-01 (n=10000)), Acc@1:  88.34 (n=10000))]
# Training Epoch 32: 100%|██████████| 469/469 [00:00<00:00, 664.38it/s, avg_metrics=Loss: 4.5726e-01 (n=60000)), Acc@1:  87.88 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 607.14it/s, avg_metrics=Loss: 4.3466e-01 (n=10000)), Acc@1:  88.60 (n=10000))]
# Training Epoch 33: 100%|██████████| 469/469 [00:00<00:00, 654.06it/s, avg_metrics=Loss: 4.4835e-01 (n=60000)), Acc@1:  88.06 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 406.31it/s, avg_metrics=Loss: 4.2630e-01 (n=10000)), Acc@1:  88.70 (n=10000))]
# Training Epoch 34: 100%|██████████| 469/469 [00:00<00:00, 654.89it/s, avg_metrics=Loss: 4.4021e-01 (n=60000)), Acc@1:  88.24 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 711.77it/s, avg_metrics=Loss: 4.1880e-01 (n=10000)), Acc@1:  88.87 (n=10000))]
# Training Epoch 35: 100%|██████████| 469/469 [00:00<00:00, 758.85it/s, avg_metrics=Loss: 4.3272e-01 (n=60000)), Acc@1:  88.38 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 512.51it/s, avg_metrics=Loss: 4.1177e-01 (n=10000)), Acc@1:  89.03 (n=10000))]
# Training Epoch 36: 100%|██████████| 469/469 [00:00<00:00, 692.88it/s, avg_metrics=Loss: 4.2579e-01 (n=60000)), Acc@1:  88.53 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 541.86it/s, avg_metrics=Loss: 4.0522e-01 (n=10000)), Acc@1:  89.08 (n=10000))]
# Training Epoch 37: 100%|██████████| 469/469 [00:00<00:00, 677.90it/s, avg_metrics=Loss: 4.1935e-01 (n=60000)), Acc@1:  88.65 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 642.11it/s, avg_metrics=Loss: 3.9908e-01 (n=10000)), Acc@1:  89.12 (n=10000))]
# Training Epoch 38: 100%|██████████| 469/469 [00:00<00:00, 660.83it/s, avg_metrics=Loss: 4.1338e-01 (n=60000)), Acc@1:  88.77 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 620.39it/s, avg_metrics=Loss: 3.9381e-01 (n=10000)), Acc@1:  89.23 (n=10000))]
# Training Epoch 39: 100%|██████████| 469/469 [00:00<00:00, 695.55it/s, avg_metrics=Loss: 4.0778e-01 (n=60000)), Acc@1:  88.85 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 479.38it/s, avg_metrics=Loss: 3.8836e-01 (n=10000)), Acc@1:  89.35 (n=10000))]
# Training Epoch 40: 100%|██████████| 469/469 [00:00<00:00, 837.92it/s, avg_metrics=Loss: 4.0255e-01 (n=60000)), Acc@1:  88.95 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 413.14it/s, avg_metrics=Loss: 3.8349e-01 (n=10000)), Acc@1:  89.47 (n=10000))]
# Training Epoch 41: 100%|██████████| 469/469 [00:00<00:00, 636.84it/s, avg_metrics=Loss: 3.9765e-01 (n=60000)), Acc@1:  89.09 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 670.96it/s, avg_metrics=Loss: 3.7900e-01 (n=10000)), Acc@1:  89.54 (n=10000))]
# Training Epoch 42: 100%|██████████| 469/469 [00:00<00:00, 766.44it/s, avg_metrics=Loss: 3.9305e-01 (n=60000)), Acc@1:  89.17 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 408.17it/s, avg_metrics=Loss: 3.7514e-01 (n=10000)), Acc@1:  89.71 (n=10000))]
# Training Epoch 43: 100%|██████████| 469/469 [00:00<00:00, 724.45it/s, avg_metrics=Loss: 3.8872e-01 (n=60000)), Acc@1:  89.29 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 442.88it/s, avg_metrics=Loss: 3.7066e-01 (n=10000)), Acc@1:  89.74 (n=10000))]
# Training Epoch 44: 100%|██████████| 469/469 [00:00<00:00, 650.55it/s, avg_metrics=Loss: 3.8463e-01 (n=60000)), Acc@1:  89.33 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 711.77it/s, avg_metrics=Loss: 3.6719e-01 (n=10000)), Acc@1:  89.88 (n=10000))]
# Training Epoch 45: 100%|██████████| 469/469 [00:00<00:00, 637.38it/s, avg_metrics=Loss: 3.8074e-01 (n=60000)), Acc@1:  89.44 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 712.99it/s, avg_metrics=Loss: 3.6357e-01 (n=10000)), Acc@1:  89.94 (n=10000))]
# Training Epoch 46: 100%|██████████| 469/469 [00:00<00:00, 669.02it/s, avg_metrics=Loss: 3.7706e-01 (n=60000)), Acc@1:  89.51 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 582.87it/s, avg_metrics=Loss: 3.6014e-01 (n=10000)), Acc@1:  90.04 (n=10000))]
# Training Epoch 47: 100%|██████████| 469/469 [00:00<00:00, 789.96it/s, avg_metrics=Loss: 3.7355e-01 (n=60000)), Acc@1:  89.60 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 417.39it/s, avg_metrics=Loss: 3.5670e-01 (n=10000)), Acc@1:  90.12 (n=10000))]
# Training Epoch 48: 100%|██████████| 469/469 [00:00<00:00, 644.75it/s, avg_metrics=Loss: 3.7021e-01 (n=60000)), Acc@1:  89.65 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 691.19it/s, avg_metrics=Loss: 3.5367e-01 (n=10000)), Acc@1:  90.16 (n=10000))]
# Training Epoch 49: 100%|██████████| 469/469 [00:00<00:00, 739.95it/s, avg_metrics=Loss: 3.6702e-01 (n=60000)), Acc@1:  89.73 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 712.68it/s, avg_metrics=Loss: 3.5058e-01 (n=10000)), Acc@1:  90.22 (n=10000))]
# Training Epoch 50: 100%|██████████| 469/469 [00:00<00:00, 632.47it/s, avg_metrics=Loss: 3.6396e-01 (n=60000)), Acc@1:  89.79 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 552.70it/s, avg_metrics=Loss: 3.4795e-01 (n=10000)), Acc@1:  90.22 (n=10000))]
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train Accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██████████████████████</td></tr><tr><td>Train Loss</td><td>████▇▇▇▆▅▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation Accuracy</td><td>▁▃▄▄▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>Validation Loss</td><td>████▇▇▇▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>50</td></tr><tr><td>Train Accuracy</td><td>89.795</td></tr><tr><td>Train Loss</td><td>0.36396</td></tr><tr><td>Validation Accuracy</td><td>90.22</td></tr><tr><td>Validation Loss</td><td>0.34795</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sunny-frost-1</strong> at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/0t92iufk' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/0t92iufk</a><br/> View project at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240925_124531-0t92iufk/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# <mark>과제</mark> wandb 로그 폴더와 checkpoint를 git에 올리지 않기 위에 `.gitignore`를 수정하라

# %% [markdown]
# (참고) shell 환경변수를 설정하여 wandb를 끌수있다.

# %%
os.environ['WANDB_DISABLED'] = 'true'
train_main_MLP()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: Currently logged in as: unknownlimitless0301 (unknownlimitless0301-university-of-suwon6591). Use `wandb login --relogin` to force relogin
# wandb version 0.18.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/jovyan/Deep_Learning_and_its_Application_2/lab_03/wandb/run-20240925_124851-75vfllzz</code>
# Syncing run <strong><a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/75vfllzz' target="_blank">good-surf-2</a></strong> to <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP</a>
#  View run at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/75vfllzz' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/75vfllzz</a>
# Using cuda:0 device
# Training Epoch 1: 100%|██████████| 469/469 [00:00<00:00, 645.85it/s, avg_metrics=Loss: 2.2932e+00 (n=60000)), Acc@1:  16.84 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 657.56it/s, avg_metrics=Loss: 2.2824e+00 (n=10000)), Acc@1:  28.23 (n=10000))]
# Training Epoch 2: 100%|██████████| 469/469 [00:00<00:00, 736.17it/s, avg_metrics=Loss: 2.2713e+00 (n=60000)), Acc@1:  35.67 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 519.15it/s, avg_metrics=Loss: 2.2588e+00 (n=10000)), Acc@1:  44.30 (n=10000))]
# Training Epoch 3: 100%|██████████| 469/469 [00:00<00:00, 718.53it/s, avg_metrics=Loss: 2.2463e+00 (n=60000)), Acc@1:  49.58 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 506.02it/s, avg_metrics=Loss: 2.2308e+00 (n=10000)), Acc@1:  56.32 (n=10000))]
# Training Epoch 4: 100%|██████████| 469/469 [00:00<00:00, 706.36it/s, avg_metrics=Loss: 2.2154e+00 (n=60000)), Acc@1:  59.11 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 445.15it/s, avg_metrics=Loss: 2.1951e+00 (n=10000)), Acc@1:  62.63 (n=10000))]
# Training Epoch 5: 100%|██████████| 469/469 [00:00<00:00, 717.59it/s, avg_metrics=Loss: 2.1753e+00 (n=60000)), Acc@1:  63.43 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 539.97it/s, avg_metrics=Loss: 2.1481e+00 (n=10000)), Acc@1:  65.89 (n=10000))]
# Training Epoch 6: 100%|██████████| 469/469 [00:00<00:00, 692.26it/s, avg_metrics=Loss: 2.1221e+00 (n=60000)), Acc@1:  65.85 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 417.81it/s, avg_metrics=Loss: 2.0854e+00 (n=10000)), Acc@1:  67.47 (n=10000))]
# Training Epoch 7: 100%|██████████| 469/469 [00:00<00:00, 626.98it/s, avg_metrics=Loss: 2.0511e+00 (n=60000)), Acc@1:  67.44 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 577.03it/s, avg_metrics=Loss: 2.0020e+00 (n=10000)), Acc@1:  68.63 (n=10000))]
# Training Epoch 8: 100%|██████████| 469/469 [00:00<00:00, 692.60it/s, avg_metrics=Loss: 1.9574e+00 (n=60000)), Acc@1:  68.50 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 734.88it/s, avg_metrics=Loss: 1.8933e+00 (n=10000)), Acc@1:  70.01 (n=10000))]
# Training Epoch 9: 100%|██████████| 469/469 [00:00<00:00, 754.49it/s, avg_metrics=Loss: 1.8377e+00 (n=60000)), Acc@1:  69.79 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 469.22it/s, avg_metrics=Loss: 1.7574e+00 (n=10000)), Acc@1:  71.49 (n=10000))]
# Training Epoch 10: 100%|██████████| 469/469 [00:00<00:00, 715.12it/s, avg_metrics=Loss: 1.6929e+00 (n=60000)), Acc@1:  71.48 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 569.08it/s, avg_metrics=Loss: 1.5991e+00 (n=10000)), Acc@1:  72.63 (n=10000))]
# Training Epoch 11: 100%|██████████| 469/469 [00:00<00:00, 595.41it/s, avg_metrics=Loss: 1.5316e+00 (n=60000)), Acc@1:  72.56 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 646.85it/s, avg_metrics=Loss: 1.4315e+00 (n=10000)), Acc@1:  74.42 (n=10000))]
# Training Epoch 12: 100%|██████████| 469/469 [00:00<00:00, 669.37it/s, avg_metrics=Loss: 1.3688e+00 (n=60000)), Acc@1:  74.15 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 714.68it/s, avg_metrics=Loss: 1.2710e+00 (n=10000)), Acc@1:  76.34 (n=10000))]
# Training Epoch 13: 100%|██████████| 469/469 [00:00<00:00, 782.34it/s, avg_metrics=Loss: 1.2193e+00 (n=60000)), Acc@1:  76.03 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 439.55it/s, avg_metrics=Loss: 1.1301e+00 (n=10000)), Acc@1:  77.96 (n=10000))]
# Training Epoch 14: 100%|██████████| 469/469 [00:00<00:00, 640.24it/s, avg_metrics=Loss: 1.0915e+00 (n=60000)), Acc@1:  77.58 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 662.08it/s, avg_metrics=Loss: 1.0134e+00 (n=10000)), Acc@1:  79.15 (n=10000))]
# Training Epoch 15: 100%|██████████| 469/469 [00:00<00:00, 668.39it/s, avg_metrics=Loss: 9.8652e-01 (n=60000)), Acc@1:  78.80 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 683.38it/s, avg_metrics=Loss: 9.1882e-01 (n=10000)), Acc@1:  80.14 (n=10000))]
# Training Epoch 16: 100%|██████████| 469/469 [00:00<00:00, 748.04it/s, avg_metrics=Loss: 9.0147e-01 (n=60000)), Acc@1:  79.79 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 366.78it/s, avg_metrics=Loss: 8.4246e-01 (n=10000)), Acc@1:  80.97 (n=10000))]
# Training Epoch 17: 100%|██████████| 469/469 [00:00<00:00, 759.10it/s, avg_metrics=Loss: 8.3241e-01 (n=60000)), Acc@1:  80.72 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 484.98it/s, avg_metrics=Loss: 7.7999e-01 (n=10000)), Acc@1:  81.73 (n=10000))]
# Training Epoch 18: 100%|██████████| 469/469 [00:00<00:00, 713.33it/s, avg_metrics=Loss: 7.7572e-01 (n=60000)), Acc@1:  81.41 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 412.87it/s, avg_metrics=Loss: 7.2879e-01 (n=10000)), Acc@1:  82.48 (n=10000))]
# Training Epoch 19: 100%|██████████| 469/469 [00:00<00:00, 646.37it/s, avg_metrics=Loss: 7.2852e-01 (n=60000)), Acc@1:  82.13 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 700.67it/s, avg_metrics=Loss: 6.8605e-01 (n=10000)), Acc@1:  83.11 (n=10000))]
# Training Epoch 20: 100%|██████████| 469/469 [00:00<00:00, 749.51it/s, avg_metrics=Loss: 6.8876e-01 (n=60000)), Acc@1:  82.81 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 491.04it/s, avg_metrics=Loss: 6.4969e-01 (n=10000)), Acc@1:  83.91 (n=10000))]
# Training Epoch 21: 100%|██████████| 469/469 [00:00<00:00, 712.16it/s, avg_metrics=Loss: 6.5481e-01 (n=60000)), Acc@1:  83.39 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 375.26it/s, avg_metrics=Loss: 6.1846e-01 (n=10000)), Acc@1:  84.42 (n=10000))]
# Training Epoch 22: 100%|██████████| 469/469 [00:00<00:00, 660.29it/s, avg_metrics=Loss: 6.2549e-01 (n=60000)), Acc@1:  83.98 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 659.79it/s, avg_metrics=Loss: 5.9138e-01 (n=10000)), Acc@1:  84.79 (n=10000))]
# Training Epoch 23: 100%|██████████| 469/469 [00:00<00:00, 662.34it/s, avg_metrics=Loss: 5.9989e-01 (n=60000)), Acc@1:  84.51 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 680.25it/s, avg_metrics=Loss: 5.6813e-01 (n=10000)), Acc@1:  85.31 (n=10000))]
# Training Epoch 24: 100%|██████████| 469/469 [00:00<00:00, 783.01it/s, avg_metrics=Loss: 5.7741e-01 (n=60000)), Acc@1:  84.98 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 430.04it/s, avg_metrics=Loss: 5.4682e-01 (n=10000)), Acc@1:  85.85 (n=10000))]
# Training Epoch 25: 100%|██████████| 469/469 [00:00<00:00, 738.97it/s, avg_metrics=Loss: 5.5747e-01 (n=60000)), Acc@1:  85.40 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 522.14it/s, avg_metrics=Loss: 5.2830e-01 (n=10000)), Acc@1:  86.18 (n=10000))]
# Training Epoch 26: 100%|██████████| 469/469 [00:00<00:00, 690.43it/s, avg_metrics=Loss: 5.3969e-01 (n=60000)), Acc@1:  85.80 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 493.22it/s, avg_metrics=Loss: 5.1167e-01 (n=10000)), Acc@1:  86.55 (n=10000))]
# Training Epoch 27: 100%|██████████| 469/469 [00:00<00:00, 697.77it/s, avg_metrics=Loss: 5.2366e-01 (n=60000)), Acc@1:  86.14 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 695.70it/s, avg_metrics=Loss: 4.9672e-01 (n=10000)), Acc@1:  86.79 (n=10000))]
# Training Epoch 28: 100%|██████████| 469/469 [00:00<00:00, 791.64it/s, avg_metrics=Loss: 5.0926e-01 (n=60000)), Acc@1:  86.50 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 520.63it/s, avg_metrics=Loss: 4.8299e-01 (n=10000)), Acc@1:  87.12 (n=10000))]
# Training Epoch 29: 100%|██████████| 469/469 [00:00<00:00, 689.94it/s, avg_metrics=Loss: 4.9615e-01 (n=60000)), Acc@1:  86.80 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 684.50it/s, avg_metrics=Loss: 4.7115e-01 (n=10000)), Acc@1:  87.51 (n=10000))]
# Training Epoch 30: 100%|██████████| 469/469 [00:00<00:00, 643.88it/s, avg_metrics=Loss: 4.8429e-01 (n=60000)), Acc@1:  87.09 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 729.06it/s, avg_metrics=Loss: 4.6009e-01 (n=10000)), Acc@1:  87.82 (n=10000))]
# Training Epoch 31: 100%|██████████| 469/469 [00:00<00:00, 656.78it/s, avg_metrics=Loss: 4.7341e-01 (n=60000)), Acc@1:  87.31 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 683.58it/s, avg_metrics=Loss: 4.4945e-01 (n=10000)), Acc@1:  88.13 (n=10000))]
# Training Epoch 32: 100%|██████████| 469/469 [00:00<00:00, 787.78it/s, avg_metrics=Loss: 4.6335e-01 (n=60000)), Acc@1:  87.55 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 376.69it/s, avg_metrics=Loss: 4.4035e-01 (n=10000)), Acc@1:  88.41 (n=10000))]
# Training Epoch 33: 100%|██████████| 469/469 [00:00<00:00, 649.07it/s, avg_metrics=Loss: 4.5427e-01 (n=60000)), Acc@1:  87.74 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 648.85it/s, avg_metrics=Loss: 4.3137e-01 (n=10000)), Acc@1:  88.51 (n=10000))]
# Training Epoch 34: 100%|██████████| 469/469 [00:00<00:00, 784.75it/s, avg_metrics=Loss: 4.4572e-01 (n=60000)), Acc@1:  87.97 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 407.03it/s, avg_metrics=Loss: 4.2378e-01 (n=10000)), Acc@1:  88.62 (n=10000))]
# Training Epoch 35: 100%|██████████| 469/469 [00:00<00:00, 751.27it/s, avg_metrics=Loss: 4.3797e-01 (n=60000)), Acc@1:  88.14 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 407.29it/s, avg_metrics=Loss: 4.1602e-01 (n=10000)), Acc@1:  88.82 (n=10000))]
# Training Epoch 36: 100%|██████████| 469/469 [00:00<00:00, 637.74it/s, avg_metrics=Loss: 4.3064e-01 (n=60000)), Acc@1:  88.29 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 668.38it/s, avg_metrics=Loss: 4.0943e-01 (n=10000)), Acc@1:  89.02 (n=10000))]
# Training Epoch 37: 100%|██████████| 469/469 [00:00<00:00, 772.57it/s, avg_metrics=Loss: 4.2393e-01 (n=60000)), Acc@1:  88.43 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 426.18it/s, avg_metrics=Loss: 4.0278e-01 (n=10000)), Acc@1:  89.09 (n=10000))]
# Training Epoch 38: 100%|██████████| 469/469 [00:00<00:00, 637.38it/s, avg_metrics=Loss: 4.1763e-01 (n=60000)), Acc@1:  88.59 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 615.57it/s, avg_metrics=Loss: 3.9711e-01 (n=10000)), Acc@1:  89.23 (n=10000))]
# Training Epoch 39: 100%|██████████| 469/469 [00:00<00:00, 686.82it/s, avg_metrics=Loss: 4.1169e-01 (n=60000)), Acc@1:  88.70 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 698.04it/s, avg_metrics=Loss: 3.9131e-01 (n=10000)), Acc@1:  89.45 (n=10000))]
# Training Epoch 40: 100%|██████████| 469/469 [00:00<00:00, 623.41it/s, avg_metrics=Loss: 4.0615e-01 (n=60000)), Acc@1:  88.83 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 646.58it/s, avg_metrics=Loss: 3.8620e-01 (n=10000)), Acc@1:  89.58 (n=10000))]
# Training Epoch 41: 100%|██████████| 469/469 [00:00<00:00, 662.80it/s, avg_metrics=Loss: 4.0105e-01 (n=60000)), Acc@1:  88.97 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 707.69it/s, avg_metrics=Loss: 3.8141e-01 (n=10000)), Acc@1:  89.67 (n=10000))]
# Training Epoch 42: 100%|██████████| 469/469 [00:00<00:00, 716.10it/s, avg_metrics=Loss: 3.9617e-01 (n=60000)), Acc@1:  89.06 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 512.77it/s, avg_metrics=Loss: 3.7679e-01 (n=10000)), Acc@1:  89.79 (n=10000))]
# Training Epoch 43: 100%|██████████| 469/469 [00:00<00:00, 694.00it/s, avg_metrics=Loss: 3.9159e-01 (n=60000)), Acc@1:  89.17 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 576.64it/s, avg_metrics=Loss: 3.7234e-01 (n=10000)), Acc@1:  89.83 (n=10000))]
# Training Epoch 44: 100%|██████████| 469/469 [00:00<00:00, 662.75it/s, avg_metrics=Loss: 3.8728e-01 (n=60000)), Acc@1:  89.24 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 602.44it/s, avg_metrics=Loss: 3.6861e-01 (n=10000)), Acc@1:  89.87 (n=10000))]
# Training Epoch 45: 100%|██████████| 469/469 [00:00<00:00, 710.40it/s, avg_metrics=Loss: 3.8315e-01 (n=60000)), Acc@1:  89.34 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 615.04it/s, avg_metrics=Loss: 3.6481e-01 (n=10000)), Acc@1:  89.97 (n=10000))]
# Training Epoch 46: 100%|██████████| 469/469 [00:00<00:00, 654.36it/s, avg_metrics=Loss: 3.7925e-01 (n=60000)), Acc@1:  89.44 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 676.31it/s, avg_metrics=Loss: 3.6096e-01 (n=10000)), Acc@1:  90.05 (n=10000))]
# Training Epoch 47: 100%|██████████| 469/469 [00:00<00:00, 647.09it/s, avg_metrics=Loss: 3.7558e-01 (n=60000)), Acc@1:  89.52 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 476.11it/s, avg_metrics=Loss: 3.5755e-01 (n=10000)), Acc@1:  90.08 (n=10000))]
# Training Epoch 48: 100%|██████████| 469/469 [00:00<00:00, 635.66it/s, avg_metrics=Loss: 3.7205e-01 (n=60000)), Acc@1:  89.61 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 676.70it/s, avg_metrics=Loss: 3.5460e-01 (n=10000)), Acc@1:  90.08 (n=10000))]
# Training Epoch 49: 100%|██████████| 469/469 [00:00<00:00, 609.53it/s, avg_metrics=Loss: 3.6870e-01 (n=60000)), Acc@1:  89.70 (n=60000)), Data_Time:  0.000 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 729.97it/s, avg_metrics=Loss: 3.5145e-01 (n=10000)), Acc@1:  90.15 (n=10000))]
# Training Epoch 50: 100%|██████████| 469/469 [00:00<00:00, 644.65it/s, avg_metrics=Loss: 3.6554e-01 (n=60000)), Acc@1:  89.78 (n=60000)), Data_Time:  0.001 (n=469)), Batch_Time:  0.001 (n=469))]
# Validation/Test: 100%|██████████| 79/79 [00:00<00:00, 758.41it/s, avg_metrics=Loss: 3.4831e-01 (n=10000)), Acc@1:  90.40 (n=10000))]
# VBox(children=(Label(value='0.004 MB of 0.027 MB uploaded\r'), FloatProgress(value=0.16374889478337754, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Train Accuracy</td><td>▁▃▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>Train Loss</td><td>████▇▇▇▆▅▅▄▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Validation Accuracy</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>Validation Loss</td><td>████▇▇▇▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>50</td></tr><tr><td>Train Accuracy</td><td>89.775</td></tr><tr><td>Train Loss</td><td>0.36554</td></tr><tr><td>Validation Accuracy</td><td>90.4</td></tr><tr><td>Validation Loss</td><td>0.34831</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-surf-2</strong> at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/75vfllzz' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP/runs/75vfllzz</a><br/> View project at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-MLP</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240925_124851-75vfllzz/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# ### Training a small Convolutional Neural Network

# %% [markdown]
# CNN은 보통 아래 4개 레이어로 구성된다
#
# - Convolutional layer
# - Activation
# - Pooling layer
# - FC layer
#
# PyTorch에는 다양한 레이어가 있지만 우리는 그중 Conv2d, ReLU, Maxpool, Linear(FC) 레이어를 이용할 예정이다.

# %% [markdown]
# #### nn.Conv2d
#
# parameter
#
# - in_channels(int) : Number of input images channel
# - out_channels(int) : Number of filters
# - kernel_size(int or tuple) : 필터의 크기는 kernel_size * kernel_size이다
# - stride(int or tuple) : Default = 1
# - padding(int or tuple) : zero padding. Default = 0

# %%
input_image = torch.rand(16, 1, 28, 28) # dummy data with batch_size 16
conv_layer1 = nn.Conv2d(in_channels = 1, out_channels = 8, kernel_size = 5)
x = conv_layer1(input_image)
print(x.shape)
# Out:
# torch.Size([16, 8, 24, 24])

# %% [markdown]
# #### nn.MaxPool2d
#
# parameter
# - kernel_size – the size of the window to take a max over
# - stride – the stride of the window. (Default = kernel_size)
# - padding – implicit zero padding to be added on both sides (default = 0)

# %%
pool_layer = nn.MaxPool2d(kernel_size = 2, stride = 2)
x = pool_layer(x)
print(x.shape)
# Out:
# torch.Size([16, 8, 12, 12])

# %% [markdown]
# 이제 CNN 모델을 구현할 준비가 완료되었다.
#
# <mark>과제</mark> 아래 구조의 CNN모델을 완성하라
#
# * 5x5 Convolutional layer with 8 filters, strides of 1, no zero padding, and ReLU activation
# * 2x2 Max pooling layer with strides of 2
# * 5x5 Convolutional layer with 16 filters, strides of 1, no zero padding, and ReLU activation
# * 2x2 Max pooling layer with strides of 2
# * Fully connected layer with 128 output units and ReLU activation
# * Fully connected layer with 64 output units and ReLU activation
# * Fully connected layer with 10 output units

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        ##### YOUR CODE START #####
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=8, kernel_size=5, stride=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=5, stride=1)
        self.fc1 = nn.Linear(16 * 4 * 4, 128)  # Fully connected layer, input size depends on image size after conv/pool
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)
        ##### YOUR CODE END #####

    def forward(self, x):
        ##### YOUR CODE START #####
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(-1, 16 * 4 * 4)  # Flatten the input
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        ##### YOUR CODE END #####

        return x

# %% [markdown]
# 파라미터 수를 스스로 계산해보고 맞게 구현됐는지 검증하라
#
# - Conv layer = filter number x filter size x filter size + bias(filter number)
# - FC layer = input size x output size + bias(output size)

# %%
cnn_model = SimpleCNN()
for name, param in cnn_model.named_parameters():
    print(f"Layer {name} # of params : {param.numel()}")
total_params = sum(p.numel() for p in cnn_model.parameters())

print(f"Total number of params : {total_params}")
# Out:
# Layer conv1.weight # of params : 200
# Layer conv1.bias # of params : 8
# Layer conv2.weight # of params : 3200
# Layer conv2.bias # of params : 16
# Layer fc1.weight # of params : 32768
# Layer fc1.bias # of params : 128
# Layer fc2.weight # of params : 8192
# Layer fc2.bias # of params : 64
# Layer fc3.weight # of params : 640
# Layer fc3.bias # of params : 10
# Total number of params : 45226

# %% [markdown]
# <mark>과제</mark> 학습을 수행하여 MLP 모델과의 결과를 비교하라.

# %%
def train_main_CNN():
    ##### YOUR CODE START #####
    # wandb 설정 및 초기화
    wandb.init(project="MNIST-CNN", config={
        "learning_rate": 1e-3,
        "epochs": 50,
        "batch_size": 128
    })
    config = wandb.config

    # 디바이스 설정 추가
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    config.device = device

    # 데이터셋 및 데이터 로더 설정
    transform = transforms.Compose([transforms.ToTensor()])
    data_root_dir = './datasets'
    
    train_dataset = datasets.MNIST(root=data_root_dir, train=True, transform=transform, download=True)
    test_dataset = datasets.MNIST(root=data_root_dir, train=False, transform=transform, download=True)
    
    train_loader = DataLoader(dataset=train_dataset, batch_size=config.batch_size, shuffle=True)
    test_loader = DataLoader(dataset=test_dataset, batch_size=config.batch_size, shuffle=False)

    # 모델 및 손실 함수, 옵티마이저 설정
    model = SimpleCNN().to(config.device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)

    # 학습 루프
    for epoch in range(config.epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(config.device), labels.to(config.device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Train Accuracy 계산
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

            if i % 100 == 99:  # 매 100 미니배치마다 로그 기록
                wandb.log({"Train Loss": running_loss / 100})
                running_loss = 0.0

        train_acc = 100 * correct_train / total_train

        # 검증 루프
        model.eval()
        running_val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(config.device), labels.to(config.device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        val_loss = running_val_loss / len(test_loader)

        # wandb 로그 기록 (Epoch, Train Loss, Train Accuracy, Validation Loss, Validation Accuracy)
        wandb.log({
            "Epoch": epoch + 1,
            "Train Accuracy": train_acc,
            "Train Loss": running_loss,
            "Validation Accuracy": val_acc,
            "Validation Loss": val_loss
        })

        print(f'Epoch {epoch + 1}, Train Accuracy: {train_acc:.2f}%, Validation Accuracy: {val_acc:.2f}%')

    # wandb 종료
    wandb.finish()
    ##### YOUR CODE END #####

# %%
train_main_CNN()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb version 0.18.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/jovyan/Deep_Learning_and_its_Application_2/lab_03/wandb/run-20240925_140742-0oeomiod</code>
# Syncing run <strong><a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN/runs/0oeomiod' target="_blank">winter-elevator-5</a></strong> to <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN</a>
#  View run at <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN/runs/0oeomiod' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN/runs/0oeomiod</a>
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./datasets/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:02<00:00, 3953896.43it/s]
# Extracting ./datasets/MNIST/raw/train-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./datasets/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 149064.40it/s]
# Extracting ./datasets/MNIST/raw/train-labels-idx1-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1046930.88it/s]
# Extracting ./datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to ./datasets/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3242643.19it/s]
# Extracting ./datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./datasets/MNIST/raw
# /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 1, Train Accuracy: 9.86%, Validation Accuracy: 9.58%
# Epoch 2, Train Accuracy: 9.86%, Validation Accuracy: 9.58%
# Epoch 3, Train Accuracy: 9.86%, Validation Accuracy: 9.58%
# Epoch 4, Train Accuracy: 9.86%, Validation Accuracy: 9.58%
# Epoch 5, Train Accuracy: 10.61%, Validation Accuracy: 12.92%
# Epoch 6, Train Accuracy: 17.77%, Validation Accuracy: 20.29%
# Epoch 7, Train Accuracy: 20.30%, Validation Accuracy: 20.06%
# Epoch 8, Train Accuracy: 19.38%, Validation Accuracy: 19.19%
# Epoch 9, Train Accuracy: 18.94%, Validation Accuracy: 19.05%
# Epoch 10, Train Accuracy: 19.04%, Validation Accuracy: 20.36%
# Epoch 11, Train Accuracy: 21.03%, Validation Accuracy: 22.42%
# Epoch 12, Train Accuracy: 23.24%, Validation Accuracy: 24.79%
# Epoch 13, Train Accuracy: 25.44%, Validation Accuracy: 26.70%
# Epoch 14, Train Accuracy: 27.49%, Validation Accuracy: 28.55%
# Epoch 15, Train Accuracy: 29.39%, Validation Accuracy: 30.39%
# Epoch 16, Train Accuracy: 31.32%, Validation Accuracy: 32.16%
# Epoch 17, Train Accuracy: 32.91%, Validation Accuracy: 33.79%
# Epoch 18, Train Accuracy: 34.77%, Validation Accuracy: 35.61%
# Epoch 19, Train Accuracy: 37.06%, Validation Accuracy: 38.96%
# Epoch 20, Train Accuracy: 40.16%, Validation Accuracy: 41.88%
# Epoch 21, Train Accuracy: 44.36%, Validation Accuracy: 48.23%
# Epoch 22, Train Accuracy: 54.01%, Validation Accuracy: 62.57%
# Epoch 23, Train Accuracy: 66.83%, Validation Accuracy: 73.54%
# Epoch 24, Train Accuracy: 74.71%, Validation Accuracy: 78.49%
# Epoch 25, Train Accuracy: 78.89%, Validation Accuracy: 81.38%
# Epoch 26, Train Accuracy: 81.67%, Validation Accuracy: 83.26%
# Epoch 27, Train Accuracy: 83.50%, Validation Accuracy: 84.69%
# Epoch 28, Train Accuracy: 84.94%, Validation Accuracy: 86.18%
# Epoch 29, Train Accuracy: 85.93%, Validation Accuracy: 87.17%
# Epoch 30, Train Accuracy: 86.74%, Validation Accuracy: 87.80%
# Epoch 31, Train Accuracy: 87.39%, Validation Accuracy: 88.58%
# Epoch 32, Train Accuracy: 88.03%, Validation Accuracy: 89.11%
# Epoch 33, Train Accuracy: 88.52%, Validation Accuracy: 89.47%
# Epoch 34, Train Accuracy: 88.97%, Validation Accuracy: 89.88%
# Epoch 35, Train Accuracy: 89.44%, Validation Accuracy: 90.25%
# Epoch 36, Train Accuracy: 89.81%, Validation Accuracy: 90.67%
# Epoch 37, Train Accuracy: 90.10%, Validation Accuracy: 90.71%
# Epoch 38, Train Accuracy: 90.44%, Validation Accuracy: 91.24%
# Epoch 39, Train Accuracy: 90.65%, Validation Accuracy: 91.27%
# Epoch 40, Train Accuracy: 90.90%, Validation Accuracy: 91.37%
# Epoch 41, Train Accuracy: 91.12%, Validation Accuracy: 91.89%
# Epoch 42, Train Accuracy: 91.29%, Validation Accuracy: 92.13%
# Epoch 43, Train Accuracy: 91.54%, Validation Accuracy: 92.16%
# Epoch 44, Train Accuracy: 91.75%, Validation Accuracy: 92.35%
# Epoch 45, Train Accuracy: 91.91%, Validation Accuracy: 92.39%
# Epoch 46, Train Accuracy: 92.14%, Validation Accuracy: 92.57%
# Epoch 47, Train Accuracy: 92.36%, Validation Accuracy: 92.69%
# Epoch 48, Train Accuracy: 92.40%, Validation Accuracy: 93.06%
# Epoch 49, Train Accuracy: 92.55%, Validation Accuracy: 93.11%
# Epoch 50, Train Accuracy: 92.69%, Validation Accuracy: 93.33%
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Train Accuracy</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▄▅▆▆▇▇▇▇████████████████</td></tr><tr><td>Train Loss</td><td>▁▁▁█▁▁█▁▁▁▁█▁▁█▁▁▆▁▁▁▁▂▁▁▂▁▁▂▁▁▁▁▂▁▁▂▁▁▁</td></tr><tr><td>Validation Accuracy</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▅▆▇▇▇▇▇████████████████</td></tr><tr><td>Validation Loss</td><td>████████████████▇▆▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>50</td></tr><tr><td>Train Accuracy</td><td>92.69333</td></tr><tr><td>Train Loss</td><td>16.51852</td></tr><tr><td>Validation Accuracy</td><td>93.33</td></tr><tr><td>Validation Loss</td><td>0.22373</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">winter-elevator-5</strong> at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN/runs/0oeomiod' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN/runs/0oeomiod</a><br/> View project at: <a href='https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN' target="_blank">https://wandb.ai/unknownlimitless0301-university-of-suwon6591/MNIST-CNN</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240925_140742-0oeomiod/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
